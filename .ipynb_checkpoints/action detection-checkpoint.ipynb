# %%
# !pip install tensorflow==2.5.1 tensorflow-gpu==2.5.1 opencv-python mediapipe sklearn matplotlib
# Out:
# Requirement already satisfied: tensorflow==2.5.1 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (2.5.1)
# Requirement already satisfied: tensorflow-gpu==2.5.1 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (2.5.1)
# Requirement already satisfied: opencv-python in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (4.6.0.66)
# Requirement already satisfied: mediapipe in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (0.8.11)
# Requirement already satisfied: sklearn in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (0.0)
# Requirement already satisfied: matplotlib in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (3.5.2)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (0.2.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (1.12.1)
# Requirement already satisfied: gast==0.4.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (0.4.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (1.15.0)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (1.34.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (1.12)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (1.1.2)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (2.5.0.dev2021032900)
# Requirement already satisfied: absl-py~=0.10 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (0.15.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (0.35.1)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (3.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (3.14.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (1.19.5)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (2.5.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (3.3.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (3.7.4.3)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (2.6.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorflow==2.5.1) (1.1.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from mediapipe) (4.7.0.68)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from mediapipe) (21.2.0)
# Requirement already satisfied: scikit-learn in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from sklearn) (1.1.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (3.3.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (58.0.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (2.26.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (2.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1) (0.6.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1) (0.2.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.1) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.1) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.1) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.1) (3.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from scikit-learn->sklearn) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\pruth\anaconda3\envs\tensorflow-gpu\lib\site-packages (from scikit-learn->sklearn) (1.7.1)

# %%
import numpy as np
import cv2
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistic= mp.solutions.holistic # Holistic Model
mp_drawing=mp.solutions.drawing_utils  #drawing utilities

# %%
def mediapipe_detection(image,model):
    image =cv2.cvtColor(image,cv2.COLOR_BGR2RGB)       # color conversion
    image.flags.writeable=False             # image is no longer writable
    results=model.process(image)           # make prediction
    image.flags.writeable=True            # image is writable
    image=cv2.cvtColor(image,cv2.COLOR_RGB2BGR) # color conversion
    return image,results

# %%
def draw_landmarks(image,results):
    mp_drawing.draw_landmarks(image,results.face_landmarks,mp_holistic.FACEMESH_TESSELATION,
                             mp_drawing.DrawingSpec(color=(80,110,10),thickness=1,circle_radius=1),
                              mp_drawing.DrawingSpec(color=(80,256,121),thickness=1,circle_radius=1))
                              
    mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_holistic.POSE_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(80,255,255),thickness=1,circle_radius=1),
                              mp_drawing.DrawingSpec(color=(80,256,121),thickness=1,circle_radius=1))
    
    
    mp_drawing.draw_landmarks(image,results.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(0,0,0),thickness=1,circle_radius=1),
                              mp_drawing.DrawingSpec(color=(80,256,121),thickness=1,circle_radius=1))
    
    
    mp_drawing.draw_landmarks(image,results.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(80,110,10),thickness=1,circle_radius=1),
                              mp_drawing.DrawingSpec(color=(80,256,121),thickness=1,circle_radius=1))

# %%
cap=cv2.VideoCapture(0)
# set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5,min_tracking_confidence=0.5)as holistic:
    while cap.isOpened():
        # read Feed
        ret,frame=cap.read()
        #make detections
        image,results=mediapipe_detection(frame,holistic)
        
        #Draw landmarks
        draw_landmarks(image,results)
        
        # show to screen
        cv2.imshow('OpenCV Feed', image)
        # break
        if cv2.waitKey(10)& 0xFF==ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
draw_landmarks(frame,results)

# %%
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))
